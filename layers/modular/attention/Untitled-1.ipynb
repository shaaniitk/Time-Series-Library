# %%
import torch
print(torch.__version__)
# For NVIDIA GPUs, check this:
# print(torch.version.cuda) 
# For AMD GPUs, you might need to check for ROCm/HIP version
# print(torch.version.hip)
# Also check if the GPU is detected
print(torch.cuda.is_available()) # This should be True for either NVIDIA or AMD (ROCm)
# Out:
# 2.4.1+cpu
# False
